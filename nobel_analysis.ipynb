# %% [markdown]
# In May 2022, OnyxData realeased a data set of nobel prize winners from 1901 t0 2019. We explore this data set in this notebook.

# %%
import atoti as tt
# Out:
# Welcome to atoti 0.6.6!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
session = tt.Session()

# %%
# loading nobel data, load the csv file directly into the nobel_data
nobel_data = session.read_csv(
    "nobel-data.csv"
)

# %%
nobel_data.head(5)
# Out:
#         firstname    surname born_country_code died_country_code gender  year  \
# 0  Wilhelm Conrad    Röntgen                DE                DE   male  1901
# 1      Hendrik A.    Lorentz                NL                NL   male  1902
# 2          Pieter     Zeeman                NL                NL   male  1902
# 3           Henri  Becquerel                FR                FR   male  1903
# 4          Pierre      Curie                FR                FR   male  1903
#
#   category  share                                 name_of_university  \
# 0  physics      1                                  Munich University
# 1  physics      2                                  Leiden University
# 2  physics      2                               Amsterdam University
# 3  physics      2                                École Polytechnique
# 4  physics      4  École municipale de physique et de chimie indu...
#
#   city_of_university country_of_university born_month  age  age_get_prize
# ...

# %%
cube = session.create_cube(nobel_data)

# %%
# defining the measure, level and hierarchy in the cube.
cube.hierarchies["year"] =  [ nobel_data["year"] ]
cube.hierarchies["share"] =  [ nobel_data["share"] ]
h,l,m = cube.hierarchies, cube.levels, cube.measures

# %% [markdown]
# # **Analysis 1. Number of Contributors**

# %% [markdown]
# The first analysis concerns the number of people who have received the nobel prize. We will slice the number of contributors acros various axes.

# %% [markdown]
# 1.1 We create a donut chart for the number of contributors depending on gender

# %%
session.visualize('What is the gender ratio of nobel prize winners?')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ The male contributors ratio is around 94% as compared to the female contributors which is only 6%.

# %% [markdown]
# 1.2 Another aspect to see is the number of contibutors per category.

# %%
session.visualize('What is the number of contributors across each category?')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ The category of medicine has the maximim number of contributors.

# %% [markdown]
# 1.3 We also see the countries with the highest number of contirbutors

# %%
session.visualize('Top 5 countries with the highest number of contributors')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ The highest number of contributors were born in the USA

# %% [markdown]
# 1.4 We slice the number of contributors across the top 5 universities

# %%
session.visualize('Top 5 universities with the highest number of contributors')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ The highest number of contributors are not affliated to any university. However, University of California has the highest
# number of contributors affliated with a university.

# %%
session.visualize('Contibutors per category by year')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ Show the timeline of nobel prize awards for each category

# %% [markdown]
# # **Analysis 2. Women in Nobel**

# %%
session.visualize('Gender per category')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ The category with the highest number of women is peace, 17 contributors.

# %%
session.visualize('Top 5 countires with female contibutors')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ USA has the highest number of female contibutors.

# %%
session.visualize('Categories for women in the top 5 countries with the highest femele contributors')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ✅ Medicine is the category with most female contributors in USA (5), followed by peace (3) then literature (2).

# %%
session.visualize('Breakdown of how the prizes in different categories were shared in the top 5 countries with the highest'+ 
                  'female contributors')
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.
